# %%
from Extract import extract, format_dict

# %%
url = 'https://scholar.google.com/citations?user=paXCr-8AAAAJ&hl=en&authuser=1'
author_details, publications = extract(url)

# %%
print(format_dict(author_details))
# Out:
# Name: Gaurav Reddy Tadkapally
# Affliation: CS Graduate at University of Southern California

# %%
print("\n\n".join(map(format_dict, publications)))
# Out:
# Title: iDrone: IoT-Enabled unmanned aerial vehicles for detecting wildfires using convolutional neural networks
# Publication Date: 2022/5
# Authors: Sibi Chakkaravarthy Sethuraman, Gaurav Reddy Tadkapally, Saraju P Mohanty, Anitha Subramanian
# ...
